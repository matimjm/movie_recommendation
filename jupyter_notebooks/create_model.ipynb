# %%
import sys
import os

# Get the path of the parent directory and add it to the system path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

import get_data

df = get_data.get_data()
# Out:
# c:\Users\DELL\Projects\movie_recommendation\TMDB_movie_dataset_v11.csv already exists
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
#       6 sys.path.append(parent_dir)
# ----> 8 import get_data
#      10 df = get_data.get_data()
#
# File c:\Users\DELL\Projects\movie_recommendation\get_data.py:86
#      82     df.drop('homepage', axis=1, inplace=True)
#      84     return df
# ---> 86 df=get_data()
#
# File c:\Users\DELL\Projects\movie_recommendation\get_data.py:26, in get_data()
#      23 list_of_data = [] # create empty list of data
#      25 # import csv directly into pandas dataframe
# ---> 26 df = pd.read_csv("TMDB_movie_dataset_v11.csv")
#      28 # Replace missing release_date values with average date
#      29
#      30
# ...

# %%
# getting the dataframe from get_data.py
import sys
import os
import get_data
# # Get the path of the parent directory and add it to the system path
# parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
# sys.path.append(parent_dir)

# Now you can import your get_data module from the parent directory


# Call the function to get your DataFrame
movies_df = get_data.get_data()

# Now you can proceed with the rest of your code to generate the embeddings
# (as outlined in the generate_embeddings.py file)
# Out:
# Did not find c:\Users\DELL\Projects\movie_recommendation\jupyter_notebooks\data\TMDB_movie_dataset_v11.csv downloading the data...
# Resuming download from 46137344 bytes (188551691 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/asaniczka/tmdb-movies-dataset-2023-930k-movies?dataset_version_number=694 (46137344/234689035) bytes left.
#  20%|█▉        | 44.0M/224M [00:01<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 13
#       4 import get_data
#       5 # # Get the path of the parent directory and add it to the system path
#       6 # parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
#       7 # sys.path.append(parent_dir)
#    (...)     11
#      12 # Call the function to get your DataFrame
# ---> 13 movies_df = get_data.get_data()
# ...
